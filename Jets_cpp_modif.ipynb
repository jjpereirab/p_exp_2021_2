// %% [markdown]
// # An introductional notebook to HEP analysis in C++
//
// <p>In this notebook you can find an easy set of commands that show some basic computing techniques commonly used in High Energy Physics (HEP) analyzes.</p>
//
// <p>It also shows how to create an histogram, fill it and draw it. Moreover it is an introduction to [ROOT](https://root.cern.ch/) too. The final output is a plot with the number of leptons.</p>
//
// Based on ATLAS opendata notebooks (http://opendata.atlas.cern/release/2020/documentation/notebooks/intro.html)

// %% [markdown]
// The library used is [ROOT](https://root.cern.ch/), a scientific data analysis software framework that provides a large set of functionalities needed to deal with big data processing, statistical analysis, visualisation and storage.

// %% [markdown]
// <p>At first we have to include several helpers that will support our analysis:</p>

// %%
#include <iostream>
#include <string>
#include <stdio.h>

// %% [markdown]
// Next we have to open the data that we want to analyze. As described above the data is stored in a _*.root_ file. This is a root file containing tracks and calorimeter clusters

// %%
TFile *file = TFile::Open("Tracks_Clusters.root");

// %% [markdown]
// The next step is to define a tree named _tree_ to get the data out of the _*.root_ file. The tree in this root file is called "JetRecoTree". We will then print the contents of the tree to find the names of the variables.

// %%
TTree *tree = (TTree*) file->Get("JetRecoTree");
tree->Print()
// Out:
// ******************************************************************************
// *Tree    :JetRecoTree: JetRecoTree                                            *
// *Entries :   102900 : Total =      3334789039 bytes  File  Size = 2227126936 *
// *        :          : Tree compression factor =   1.50                       *
// ******************************************************************************
// *Br    0 :EventNumber : EventNumber/l                                        *
// *Entries :   102900 : Total  Size=     836872 bytes  File Size  =     448624 *
// *Baskets :      127 : Basket Size=       7219 bytes  Compression=   1.86     *
// *............................................................................*
// *Br    1 :RunNumber : RunNumber/l                                            *
// *Entries :   102900 : Total  Size=     836610 bytes  File Size  =      20416 *
// *Baskets :      127 : Basket Size=       7219 bytes  Compression=  40.84     *
// ...

// %% [markdown]
// <p>The next step is to extract the varibles we want from the dataset. We will explore two jet types: "Reco" (reconstructed from the calorimeter) and "Truth"(particle level). Activate "Event Weight".

// %%
float evtw = -1;
vector<float> *reco_R4_pt;
vector<float> *truth_R4_pt;

tree->SetBranchAddress("EventWeight", &evtw);
tree->SetBranchAddress("RecoJets_R4_pt", &reco_R4_pt);
tree->SetBranchAddress("TruthJets_R4_pt", &truth_R4_pt);

// %% [markdown]
// Create Canvas

// %%
TCanvas *canvas = new TCanvas("Canvas","",600,400);

// %% [markdown]
// Create histograms: Leading jet pT and all jets pT

// %%
TH1F *hist_leadreco_pt = new TH1F("Lead Reco-jet","Leading jet pT; pT(GeV);Events",50,10,200);
TH1F *hist_reco_pt = new TH1F("Reco-jet","Jet pT; pT(GeV);Events",50,10,200);

// %% [markdown]
// Loop and fill histograms

// %%
int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   
    if(reco_R4_pt->size()>0){
        hist_leadreco_pt->Fill(reco_R4_pt->at(0)/1000.,evtw);  
        for(int j=0; j < reco_R4_pt->size(); j++){
            hist_reco_pt->Fill(reco_R4_pt->at(j)/1000.,evtw);     
        }
    }
}

std::cout << "Done!" << std::endl;
// Out:
// Done!

// %% [markdown]
// <p>Draw</p>

// %%
hist_reco_pt->SetMarkerStyle(20);
hist_reco_pt->SetMarkerColor(kRed);
hist_reco_pt->Draw("");
hist_leadreco_pt->SetMarkerStyle(21);
hist_leadreco_pt->Draw("same");
canvas->SetLogy();
canvas->Draw();

// %% [markdown]
// <b>Excercises:
//     1. Compare the leading truth jet pT with the leading reco jet pT, with and without event weights.
//     2. Repeat for all jets pT.
// </b>

// %% [markdown]
// ## 1.1 with event weight ##

// %%
// float evtw = -1;
// vector<float> *reco_R4_pt;
// vector<float> *truth_R4_pt;

// tree->SetBranchAddress("EventWeight", &evtw);
// tree->SetBranchAddress("RecoJets_R4_pt", &reco_R4_pt);
// tree->SetBranchAddress("TruthJets_R4_pt", &truth_R4_pt);

// TCanvas *canvas = new TCanvas("Canvas","",600,400);

//-----------------------------

TH1F *hist_leadreco_pt = new TH1F("Lead Reco-jet","Leading jet pT; pT(GeV);Events",50,10,200);
TH1F *hist_leadtruth_pt = new TH1F("Lead Truth-jet","Leading jet pT; pT(GeV);Events",50,10,200);

//-----------------------------

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   
    if(reco_R4_pt->size()>0){
        hist_leadreco_pt->Fill(reco_R4_pt->at(0)/1000.,evtw);  
    }
    
    if(truth_R4_pt->size()>0){
        hist_leadtruth_pt->Fill(truth_R4_pt->at(0)/1000.,evtw);  
    }
}

//-----------------------------

hist_leadreco_pt->SetMarkerStyle(20);
hist_leadreco_pt->SetMarkerColor(kRed);
hist_leadreco_pt->Draw("");
hist_leadtruth_pt->SetMarkerStyle(21);
hist_leadtruth_pt->Draw("same");
canvas->SetLogy();
canvas->Draw();

// %% [markdown]
// ## 1.2 without event weight ##

// %%
TH1F *hist_leadreco_pt_no_weight = new TH1F("Lead Reco-jet no weight","Leading jet pT; pT(GeV);Events",50,10,200);
TH1F *hist_leadtruth_pt_no_weight = new TH1F("Lead Truth-jet no weight","Leading jet pT; pT(GeV);Events",50,10,200);

//-----------------------------

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   
    if(reco_R4_pt->size()>0){
        hist_leadreco_pt_no_weight->Fill(reco_R4_pt->at(0)/1000.);  
    }
    
    if(truth_R4_pt->size()>0){
        hist_leadtruth_pt_no_weight->Fill(truth_R4_pt->at(0)/1000.);  
    }
}

//-----------------------------

hist_leadreco_pt_no_weight->SetMarkerStyle(20);
hist_leadreco_pt_no_weight->SetMarkerColor(kRed);
hist_leadreco_pt_no_weight->Draw("p");
hist_leadtruth_pt_no_weight->SetMarkerStyle(21);
hist_leadtruth_pt_no_weight->Draw("same");
canvas->SetLogy();
canvas->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: Lead Reco-jet no weight (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: Lead Truth-jet no weight (Potential memory leak).

// %% [markdown]
// ## 2.1 all jets with event weight ##

// %%
TH1F *hist_reco_all_pt_weight = new TH1F("All Reco-jet with weight","Leading jet pT; pT(GeV);Events",50,10,200);
TH1F *hist_truth_all_pt_weight = new TH1F("All Truth-jet with weight","Leading jet pT; pT(GeV);Events",50,10,200);

//-----------------------------

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   
    if(reco_R4_pt->size()>0){
        for(int j=0; j < reco_R4_pt->size(); j++){
            hist_reco_all_pt_weight->Fill(reco_R4_pt->at(j)/1000.,evtw);     
        }
    }
    
    if(truth_R4_pt->size()>0){
        for(int j=0; j < truth_R4_pt->size(); j++){
            hist_truth_all_pt_weight->Fill(truth_R4_pt->at(j)/1000.,evtw);    
        }
    }
}

//-----------------------------

hist_reco_all_pt_weight->SetMarkerStyle(20);
hist_reco_all_pt_weight->SetMarkerColor(kRed);
hist_reco_all_pt_weight->Draw("p");
hist_truth_all_pt_weight->SetMarkerStyle(21);
hist_truth_all_pt_weight->Draw("same");
canvas->SetLogy();
canvas->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: All Reco-jet with weight (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: All Truth-jet with weight (Potential memory leak).

// %% [markdown]
// ## 2.2 all jets without event weight ##

// %%
TH1F *hist_reco_all_pt_no_weight = new TH1F("All Reco-jet without weight","Leading jet pT; pT(GeV);Events",50,10,200);
TH1F *hist_truth_all_pt_no_weight = new TH1F("All Truth-jet without weight","Leading jet pT; pT(GeV);Events",50,10,200);

//-----------------------------

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   
    if(reco_R4_pt->size()>0){
        for(int j=0; j < reco_R4_pt->size(); j++){
            hist_reco_all_pt_no_weight->Fill(reco_R4_pt->at(j)/1000.);     
        }
    }
    
    if(truth_R4_pt->size()>0){
        for(int j=0; j < truth_R4_pt->size(); j++){
            hist_truth_all_pt_no_weight->Fill(truth_R4_pt->at(j)/1000.);    
        }
    }
}

//-----------------------------

hist_reco_all_pt_no_weight->SetMarkerStyle(20);
hist_reco_all_pt_no_weight->SetMarkerColor(kRed);
hist_reco_all_pt_no_weight->Draw("p");
hist_truth_all_pt_no_weight->SetMarkerStyle(21);
hist_truth_all_pt_no_weight->Draw("same");
canvas->SetLogy();
canvas->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: All Reco-jet without weight (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: All Truth-jet without weight (Potential memory leak).

// %% [markdown]
// -----------------------

// %% [markdown]
// Now we will study the jets pileup dependence

// %%
UInt_t npv = -1;
tree->SetBranchAddress("NPV", &npv);

float mu = -1;
tree->SetBranchAddress("mu_average", &mu);

// %% [markdown]
// Plot jet pt vs. pileup

// %%
TH2F *hist_jetpt_npv = new TH2F("Reco-jet pT vs. NPV",";NPV; jet pT",50,1,50, 20, 0, 200);
TProfile *prof_jetpt_npv = new TProfile("Profile Reco-jet pT vs. NPV",";NPV; jet pT",50,1,50, 0, 200);

// %% [markdown]
// Fill the histograms: Make a cut to accept events with at least one jet and require the leading jet to have pT above 20 GeV

// %%
int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && reco_R4_pt->at(0)>20000.){
        for(int j=0; j<reco_R4_pt->size(); j++){
        hist_jetpt_npv->Fill(reco_R4_pt->at(j)/1000.,npv,evtw);
        prof_jetpt_npv->Fill(reco_R4_pt->at(j)/1000.,npv,evtw);
        }
    }
}

std::cout << "Done!" << std::endl;
// Out:
// Done!

// %%
TCanvas *canvas2 = new TCanvas("Canvas2","",800,600);
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas2

// %%
hist_jetpt_npv->Draw("colz");
canvas2->Draw();

// %%
prof_jetpt_npv->Draw("");
canvas2->Draw();

// %% [markdown]
//  ### Fill() with correct order ###

// %%
TH2F *hist_jetpt_npv2 = new TH2F("Reco-jet pT vs. NPV 2",";NPV; jet pT",50,1,50, 20, 0, 200);
TProfile *prof_jetpt_npv2 = new TProfile("Profile Reco-jet pT vs. NPV 2",";NPV; jet pT",50,1,50, 0, 200);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && reco_R4_pt->at(0)>20000.){
        for(int j=0; j<reco_R4_pt->size(); j++){
        hist_jetpt_npv2->Fill(npv, reco_R4_pt->at(j)/1000.,evtw);
        prof_jetpt_npv2->Fill(npv, reco_R4_pt->at(j)/1000.,evtw);
        }
    }
}

TCanvas *canvas3 = new TCanvas("Canvas3","",600,400);
hist_jetpt_npv2->Draw("colz");
canvas3->Draw();
// Out:
// Done!

// %%
prof_jetpt_npv2->Draw("");
canvas3->Draw();

// %% [markdown]
// <b>Excercise:
// 3. Make plots for reco and truth jet pT vs. pileup. Interpret your results.
// </b>

// %% [markdown]
// ### 3.1 Trackjets pT vs NPV ###

// %%
vector<float> *TJ_R4_pt;
tree->SetBranchAddress("TrackJets_R4_pt", &TJ_R4_pt);

//-----------------------------------
TH2F *hist_TJpt_npv = new TH2F("TrackJets pT vs. NPV",";NPV; TrackJets pT",50,1,50, 20, 0, 200);
TProfile *prof_TJpt_npv = new TProfile("Profile TrackJets pT vs. NPV",";NPV; TrackJets pT",50,1,50, 0, 200);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(TJ_R4_pt->size()!=0 && TJ_R4_pt->at(0)>20000.){
        for(int j=0; j<TJ_R4_pt->size(); j++){
        hist_TJpt_npv->Fill(npv, TJ_R4_pt->at(j)/1000.,evtw);
        prof_TJpt_npv->Fill(npv, TJ_R4_pt->at(j)/1000.,evtw);
        }
    }
}

TCanvas *canvas31 = new TCanvas("Canvas31","",600,400);
hist_TJpt_npv->Draw("colz");
canvas31->Draw();

// %%
prof_TJpt_npv->Draw("");
canvas31->Draw();

// %% [markdown]
// ### 3.2 truth-jet pT vs NPV ###

// %%
TH2F *hist_truthpt_npv = new TH2F("Truth pT vs. NPV",";NPV; Truth pT",50,1,50, 20, 0, 200);
TProfile *prof_truthpt_npv = new TProfile("Profile Truth pT vs. NPV",";NPV; Truth pT",50,1,50, 0, 200);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(truth_R4_pt->size()!=0 && truth_R4_pt->at(0)>20000.){
        for(int j=0; j<truth_R4_pt->size(); j++){
        hist_truthpt_npv->Fill(npv, truth_R4_pt->at(j)/1000.,evtw);
        prof_truthpt_npv->Fill(npv, truth_R4_pt->at(j)/1000.,evtw);
        }
    }
}

TCanvas *canvas32 = new TCanvas("Canvas32","",600,400);
hist_truthpt_npv->Draw("colz");
canvas32->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas32

// %%
prof_truthpt_npv->Draw("");
canvas32->Draw();

// %% [markdown]
// ---------------

// %% [markdown]
// Plot the JVF (Jet Vertex Fraction) variable

// %%
vector<float> *reco_R4_jvf;
tree->SetBranchAddress("RecoJets_R4_jvf", &reco_R4_jvf);

// %%
TH1F *hist_leadreco_jvf = new TH1F("Lead Reco-jet JVF","Leading jet JVF; JVF;Events",20,-1,1);
TH1F *hist_leadreco100_jvf = new TH1F("Lead Reco-jet JVF 100","Leading jet JVF; JVF;Events",20,-1,1);

// %%
int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && reco_R4_pt->at(0)>20000.){
        hist_leadreco_jvf->Fill(reco_R4_jvf->at(0), evtw);
        if(reco_R4_pt->at(0)>100000.){hist_leadreco100_jvf->Fill(reco_R4_jvf->at(0), evtw);}
        
    }
}

std::cout << "Done!" << std::endl;
// Out:
// Done!

// %%
TCanvas *canvas2 = new TCanvas("Canvas2","",600,400);

hist_leadreco_jvf->SetMarkerStyle(20);
hist_leadreco_jvf->SetMarkerColor(kRed);
hist_leadreco_jvf->DrawNormalized("");
hist_leadreco100_jvf->SetMarkerStyle(22);
hist_leadreco100_jvf->SetMarkerColor(kBlue);
hist_leadreco100_jvf->DrawNormalized("same");
canvas2->Draw();

// %% [markdown]
// <b>Excercise:
// 4. Use a |JVF|>0.5 cut to compare the leading jet pT for truth jets, reco jets (w.o. the cut), and reco jets (with the cut)
// 5. Repeat the same plots and comparisons with "Track-jets" and verify that they are stable against pileup
// </b>

// %% [markdown]
// ### 4.1 leading reco with |JVF|>0.5 ###

// %%
vector<float> *TJ_R4_pt;
tree->SetBranchAddress("TrackJets_R4_pt", &TJ_R4_pt);

//-----------------------------------
TH2F *hist_TJpt_npv = new TH2F("TrackJets pT vs. NPV",";NPV; TrackJets pT",50,1,50, 20, 0, 200);
TProfile *prof_TJpt_npv = new TProfile("Profile TrackJets pT vs. NPV",";NPV; TrackJets pT",50,1,50, 0, 200);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && reco_R4_pt->at(0)>20000. && fabs(reco_R4_jvf->at(0))>0.5){
        for(int j=0; j<TJ_R4_pt->size(); j++){
        hist_TJpt_npv->Fill(npv, TJ_R4_pt->at(j)/1000.,evtw);
        prof_TJpt_npv->Fill(npv, TJ_R4_pt->at(j)/1000.,evtw);
        }
    }
}

TCanvas *canvas31 = new TCanvas("Canvas31","",600,400);
hist_TJpt_npv->Draw("colz");
canvas31->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: TrackJets pT vs. NPV (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: Profile TrackJets pT vs. NPV (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas31

// %%
prof_TJpt_npv->Draw("");
canvas31->Draw();

// %% [markdown]
// ---------------

// %%
TH1F *hist_leadreco_jvf_cut = new TH1F("Lead Reco-jet JVF cut","Leading jet JVF; JVF;Events",20,-1,1);
TH1F *hist_leadreco100_jvf_cut = new TH1F("Lead Reco-jet JVF 100 cut","Leading jet JVF; JVF;Events",20,-1,1);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && reco_R4_pt->at(0)>20000. && fabs(reco_R4_jvf->at(0))>0.5){
        hist_leadreco_jvf_cut->Fill(reco_R4_jvf->at(0), evtw);
        if(reco_R4_pt->at(0)>100000.){hist_leadreco100_jvf_cut->Fill(reco_R4_jvf->at(0), evtw);}
    }
}

TCanvas *canvas41 = new TCanvas("Canvas41","",600,400);

hist_leadreco_jvf_cut->SetMarkerStyle(20);
hist_leadreco_jvf_cut->SetMarkerColor(kRed);
hist_leadreco_jvf_cut->DrawNormalized("");
hist_leadreco100_jvf_cut->SetMarkerStyle(22);
hist_leadreco100_jvf_cut->SetMarkerColor(kBlue);
hist_leadreco100_jvf_cut->DrawNormalized("same");

canvas41->Draw();

// %% [markdown]
// ### 4.2 leading truth without JVF condition ###

// %%
TH1F *hist_leadtruth_jvf = new TH1F("Lead truth-jet JVF","Leading jet JVF; JVF;Events",20,-1,1);
TH1F *hist_leadtruth100_jvf = new TH1F("Lead truth-jet JVF 100","Leading jet JVF; JVF;Events",20,-1,1);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && truth_R4_pt->size()!=0 && truth_R4_pt->at(0)>20000.){
        hist_leadtruth_jvf->Fill(reco_R4_jvf->at(0), evtw);
        if(truth_R4_pt->at(0)>100000.){hist_leadtruth100_jvf->Fill(reco_R4_jvf->at(0), evtw);}
    }
}

TCanvas *canvas42 = new TCanvas("Canvas42","",600,400);

hist_leadtruth_jvf->SetMarkerStyle(20);
hist_leadtruth_jvf->SetMarkerColor(kRed);
hist_leadtruth_jvf->DrawNormalized("");
hist_leadtruth100_jvf->SetMarkerStyle(22);
hist_leadtruth100_jvf->SetMarkerColor(kBlue);
hist_leadtruth100_jvf->DrawNormalized("same");

canvas42->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: Lead truth-jet JVF (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: Lead truth-jet JVF 100 (Potential memory leak).
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas42

// %% [markdown]
// ### 4.3 leading truth with |JVF|>0.5 ###

// %%
TH1F *hist_leadtruth_jvf_cut = new TH1F("Lead truth-jet JVF cut","Leading jet JVF; JVF;Events",20,-1,1);
TH1F *hist_leadtruth100_jvf_cut = new TH1F("Lead truth-jet JVF 100 cut","Leading jet JVF; JVF;Events",20,-1,1);

int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(reco_R4_pt->size()!=0 && truth_R4_pt->size()!=0 && truth_R4_pt->at(0)>20000. && fabs(reco_R4_jvf->at(0))>0.5){
        hist_leadtruth_jvf_cut->Fill(reco_R4_jvf->at(0), evtw);
        if(truth_R4_pt->at(0)>100000.){hist_leadtruth100_jvf_cut->Fill(reco_R4_jvf->at(0), evtw);}
    }
}

TCanvas *canvas43 = new TCanvas("Canvas43","",600,400);

hist_leadtruth_jvf_cut->SetMarkerStyle(20);
hist_leadtruth_jvf_cut->SetMarkerColor(kRed);
hist_leadtruth_jvf_cut->DrawNormalized("");
hist_leadtruth100_jvf_cut->SetMarkerStyle(22);
hist_leadtruth100_jvf_cut->SetMarkerColor(kBlue);
hist_leadtruth100_jvf_cut->DrawNormalized("same");

canvas43->Draw();
// Out:
// Warning in <TFile::Append>: Replacing existing TH1: Lead truth-jet JVF cut (Potential memory leak).
// Warning in <TFile::Append>: Replacing existing TH1: Lead truth-jet JVF 100 cut (Potential memory leak).

// %% [markdown]
// -------------

// %% [markdown]
// Now we will study the jet response: the ratio between the pT of the jet to the truth jet. First we should "match" the jets and the truth jets. We will use the distance DeltaR between the two, but first we should define them as four-vectors:

// %%
vector<float> *reco_R4_eta;
vector<float> *reco_R4_phi;
vector<float> *reco_R4_m;

vector<float> *truth_R4_eta;
vector<float> *truth_R4_phi;
vector<float> *truth_R4_m;

tree->SetBranchAddress("RecoJets_R4_eta", &reco_R4_eta);
tree->SetBranchAddress("RecoJets_R4_phi", &reco_R4_phi);
tree->SetBranchAddress("RecoJets_R4_m", &reco_R4_m);
tree->SetBranchAddress("TruthJets_R4_eta", &truth_R4_eta);
tree->SetBranchAddress("TruthJets_R4_phi", &truth_R4_phi);
tree->SetBranchAddress("TruthJets_R4_m", &truth_R4_m);

// %%
TH1F *hist_DR_reco_truth = new TH1F("Delta R reco","Delta R; #Delta R; Events",20,0,2);

// %%
int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);

    if(truth_R4_pt->size()!=0 && truth_R4_pt->at(0)>20000.){
        TLorentzVector truthJet;
        truthJet.SetPtEtaPhiM(truth_R4_pt->at(0),truth_R4_eta->at(0),truth_R4_phi->at(0),truth_R4_m->at(0));        
        if(reco_R4_pt->size()!=0 && fabs(reco_R4_jvf->at(0))>0.5){
            TLorentzVector recoJet;
            recoJet.SetPtEtaPhiM(reco_R4_pt->at(0),reco_R4_eta->at(0),reco_R4_phi->at(0),reco_R4_m->at(0));        
 
            //Plot the Delta R
            hist_DR_reco_truth->Fill(truthJet.DeltaR(recoJet),evtw);
        }
    }
}

std::cout << "Done!" << std::endl;
// Out:
// Done!

// %%
hist_DR_reco_truth->Scale(1/hist_DR_reco_truth->Integral());
hist_DR_reco_truth->DrawNormalized("");
canvas2->Draw();

// %% [markdown]
// <b>Excercise:
// 6. Repeat for track-jets and make a plot comparing three cases: reco-jets with and without the JVF cut, and track-jets
// </b>

// %% [markdown]
// <b>Excercises:
// 7. Plot the response: For matched jets (use DeltaR<0.3), plot pTjet/pTtruth for 3 cases: truth_pT>20 GeV, 100 GeV, 500 GeV. Do this for track jets and reco jets (two plots).
// 8. Investigate the Large-R jets:
//     (a) Plot the leading jet pT for reco_R10 and reco_R10_Trimmed jets
//     (b) Plot the leading jet pT for truth_R10 and truth_R10_Trimmed jets
//     (c) Compare all plots. How can you explain the differences?
//     (d) Make the same comparisson for the jet mass.
//
// </b>
